# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Variational distributions

# %%
import latenta as la
import numpy as np
import pandas as pd

# %%
observed_value = pd.Series(np.random.normal(2., 1, (100, )), name = "observed")
observed_value.index.name = "sample"

observed_definition = la.Definition.from_dataarray(observed_value)

# %%
loc_prior = la.distributions.Normal()
loc = la.Latent(loc_prior)

scale_prior = la.distributions.LogNormal()
scale = la.Latent(scale_prior)

# %%
dist = la.distributions.Normal(loc = loc, scale = scale)

# %%
observed = la.Observed(observed_value, dist)

# %%
la.interpretation.ComponentGraph(observed)
# Out:
# <img src='data:image/png;base64,...' style='zoom:0.24'>

# %%
inference = la.infer.svi.SVI(observed, [la.infer.loss.ELBO()], la.infer.optim.Adam(lr = 0.01))
trainer = la.infer.trainer.Trainer(inference)

# %%
trace = trainer.train(10000)
trace.plot();
# Out:
# ...
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-9-1c821331d5d9> in <module>
# ----> 1 trace = trainer.train(10000)
#       2 trace.plot();
#
# w:\thesis\projects\latenta\latenta\src\latenta\infer\trainer\__init__.py in train(self, num_iterations, trace, description)
#      31             progress.update()
#      32             # calculate the loss and take a gradient step
# ---> 33             loss = self.inference.step(trace)
#      34             losses.append(loss)
#      35
#
# w:\thesis\projects\latenta\latenta\src\latenta\infer\svi\svi.py in step(self, trace)
#     100
#     101         for loss in self.losses:
# --> 102             loss.loss_model(trace)
#     103         for loss in self.losses:
#     104             loss.loss_guide(trace)
#
# w:\thesis\projects\latenta\latenta\src\latenta\infer\loss\__init__.py in loss_model(self, trace)
# ...

# %% [markdown]
# ## Comparing variational distributions

# %% [markdown]
# ### KL divergence

# %%
la
# Out:
# <module 'latenta' from 'w:\\thesis\\projects\\latenta\\latenta\\src\\latenta\\__init__.py'>
